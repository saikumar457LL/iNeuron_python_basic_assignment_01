# %% [markdown]
# # Q1
#
# ### In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# 1. *
# 2. 'hello'
# 3. -87.8
# 4. -
# 5. /
# 6. +
# 7. 6
#
# # Ans:
#
# `Values are` </br>
#     'hello' </br>
#     -87.8 </br>
#     6 </br>
#
# `Expressions are` </br>
#     *</br>
#     -</br>
#     /</br>
#     +</br>

# %% [markdown]
# # Q2
#
# ### What is the difference between string and variable?
#
# # Ans:
#    <b>String :</b> --> String is nothing but a character or a combination of characters which are enclosed in single quotes(' ') or double quotes (" ")</br> String is used to store the characters.</br>
#    <b>Variable: </b> --> Variable are used to store the data types</br>

# %% [markdown]
# # Q3
#
# ### Describe three different data types.
#
# # Ans:
#
# <b>Int :</b> is used to store integer values, like 1,2,3,..</br>
# <b>float :</b> is used to store decimal values, like 1.0,2.0,...</br>
# <b>str :</b> is used to store characters which are enclosed in single quotes (' ') or double quotes (" ") </br>
# <b>bool: </b> They store only either 1 or 0 only

# %% [markdown]
# # Q4
#
# What is an expression made up of? What do all expressions do?
#
# # Ans:
#
# <b>Expression :</b> is made of operators,values and variables.</br>
# All expressions do:</br>
# <i>Assignment Expression (=) </i>: assign's the any type of data to a variables. eg: x=9, y=9+2, z=list(("one","two"))</br>
# <i>Postfix Expression: </i>:  he operator is placed after the operands</br>
# <i>Iteger Expression: </i>: produces an integer result after evaluating the expression</br>

# %% [markdown]
# # Q5
# This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
#
# # Ans:
# <b>Expression: </b> the evaluation of values and operators results expression. eg: 2+7,9*9,spam=10</br>
# <b>Statement: </b> the final evaluation of expression which is stored in a variable is becomes <i>Statement</i>. eg: x=3 * 3 , here 3 * 3 is an expression which is evaluated first and then stored in varialbe, and that variable becomes statement.

# %% [markdown]
# # Q6
#
# After running the following code, what does the variable bacon contain?
#
#     bacon = 22
#     bacon + 1
#
# # Ans:
#     bacon contains 23

# %% [markdown]
# # Q7
#
# What should the values of the following two terms be?
#
#     'spam'+'spamspam'
#     'spam' * 3
#
# # Ans:
#
#     'spam'+'spamspam' --> spamspamspam
#     'spam' * 3 --> spamspamspam

# %% [markdown]
# # Q8
#
# Why is eggs a valid variable name while 100 is invalid?
#
# # Ans:
#     Acroding to python a variable start's with characters we can also use underscore sign
#     A variable can't be created with  numerical type and also python operators
#     we can also use numerical type while after the characters eg: abc2 = 8, ab89 = 34
#
#     eggs --> here eggs are valid. Because they are not started with operators and also numerical type.
#     100  --> not valid. Because they started with numerical data

# %% [markdown]
# # Q9
#
# What three functions can be used to get the integer, floating-point number, or string
# version of a value?
#
# # Ans:
#
# <i>integer</i> -->  int()</br>
# <i>floating-point number</i> --> float() and also double()</br>
# <i>string</i> --> str()

# %% [markdown]
# # Q10
#
# Why does this expression cause an error? How can you fix it?</br>
#     'I have eaten ' + 99 + 'burritos.'
#
# # Ans:
# we can't concatenate string type with numerical type.</br>
# we can fix by changing numerical type to string type --> str(99)</br>
#
# "I have eaten " + str(99) + "burritos."

# %%
# Fix

print("I have eaten "+str(99) + "burritos.")
# Out:
# I have eaten 99burritos.
